# %% [markdown]
# **Talent acquisition strategy:** <br>Identify the academic backgrounds and departments most interested in AI for targeted recruitment.

# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv('/content/Cumulative_Activity_Form_Responses.csv')

# %% [markdown]
# **Data processing and exploration**

# %%
data.head()
# Out:
#   Your Full Name  \
# 0      Student 1
# 1      Student 2
# 2      Student 3
# 3      Student 4
# 4      Student 5
#
#   Are you an undergraduate, hold a Bachelor's, or a Master's degree?  \
# 0                                         Bachelor's
# 1                                            Masters
# 2                                      Undergraduate
# 3                                         Bachelor's
# 4                                         Bachelor's
#
#   Which academic department are you currently affiliated with?  \
# 0                                    Web Development
# 1                                   Computer Science
# 2                                    Web Development
# 3                               Software Development
# 4                                          Marketing
#
#                  Why are you learning generative AI?  \
# 0  to help me develop strategies that can help me...
# 1  creating models that can produce new data samp...
# 2         All about gemerayive AI and how to use AI
# 3                                Help me with my job
# 4                         something about our future
#
#   Do you need online career support from us?  \
# 0                                        Yes
# 1                                        Yes
# 2                                        Yes
# 3                                        Yes
# 4                                         No
#
#   Do you require online learning support in AI?
# 0                                           Yes
# 1                                            No
# 2                                           Yes
# 3                                           Yes
# 4                                           Yes

# %%
data.shape
# Out:
# (23, 6)

# %%
# Copy the data
df_general = data.copy()

# Rename the columns for easy access
df_general.columns = ['Name', 'Degree', 'Department', 'Motivation', 'Career_Support', 'Learning_Support']

df_general.head(2)
# Out:
#         Name      Degree        Department  \
# 0  Student 1  Bachelor's   Web Development
# 1  Student 2     Masters  Computer Science
#
#                                           Motivation Career_Support  \
# 0  to help me develop strategies that can help me...            Yes
# 1  creating models that can produce new data samp...            Yes
#
#   Learning_Support
# 0              Yes
# 1               No

# %%
# Filter rows where individuals require online learning support in AI
df = df_general[df_general.Learning_Support == 'Yes']
df.shape[0]
# Out:
# 15

# %%
# Count the number of interested individuals per degree and department
df = df.groupby(['Degree', 'Department']).size().reset_index(name='Count')
df
# Out:
#            Degree              Department  Count
# 0      Bachelor's     Business Management      2
# 1      Bachelor's               Marketing      2
# 2      Bachelor's    Software Development      1
# 3      Bachelor's         Web Development      1
# 4         Masters  Information Technology      1
# 5         Masters               Marketing      1
# 6         Masters    Software Development      1
# 7   Undergraduate     Business Management      1
# 8   Undergraduate        Computer Science      1
# 9   Undergraduate  Information Technology      2
# 10  Undergraduate         Web Development      2

# %%
# Sort the data by count in descending order
df = df.sort_values(by='Count', ascending=False)
df
# Out:
#            Degree              Department  Count
# 0      Bachelor's     Business Management      2
# 1      Bachelor's               Marketing      2
# 9   Undergraduate  Information Technology      2
# 10  Undergraduate         Web Development      2
# 2      Bachelor's    Software Development      1
# 3      Bachelor's         Web Development      1
# 4         Masters  Information Technology      1
# 5         Masters               Marketing      1
# 6         Masters    Software Development      1
# 7   Undergraduate     Business Management      1
# 8   Undergraduate        Computer Science      1

# %% [markdown]
# **Data visualization**

# %%
# Horizontal Bar Chart
fig = px.bar(df, x='Count', y='Degree', color='Department',
             title='Interest in AI Learning Support by Degree and Department',
             labels={'Count':'Number of Individuals', 'Degree':'Academic Degree'},
             color_continuous_scale=px.colors.sequential.Plasma,
             template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="94cb86d4-9315-4226-a0cc-990ca0519012" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94cb86d4-9315-4226-a0cc-990ca0519012")) {                    Plotly.newPlot(                        "94cb86d4-9315-4226-a0cc-990ca0519012",                        [{"alignmentgroup":"True","hovertemplate":"Department=Business Management\u003cbr\u003eNumber of Individuals=%{x}\u003cbr\u003eAcademic Degree=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Business Management","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Business Management","offsetgroup":"Business Management","orientation":"h","showlegend":true,"textposition":"auto","x":[2,1],"xaxis":"x","y":["Bachelor's","Undergraduate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=Marketing\u003cbr\u003eNumber of Individuals=%{x}\u003cbr\u003eAcademic Degree=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Marketing","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Marketing","offsetgroup":"Marketing","orientation":"h","showlegend":true,"textposition":"auto","x":[2,1],"xaxis":"x","y":["Bachelor's","Masters"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=Information Technology\u003cbr\u003eNumber of Individuals=%{x}\u003cbr\u003eAcademic Degree=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Information Technology","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Information Technology","offsetgroup":"Information Technology","orientation":"h","showlegend":true,"textposition":"auto","x":[2,1],"xaxis":"x","y":["Undergraduate","Masters"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=Web Development\u003cbr\u003eNumber of Individuals=%{x}\u003cbr\u003eAcademic Degree=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Web Development","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Web Development","offsetgroup":"Web Development","orientation":"h","showlegend":true,"textposition":"auto","x":[2,1],"xaxis":"x","y":["Undergraduate","Bachelor's"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=Software Development\u003cbr\u003eNumber of Individuals=%{x}\u003cbr\u003eAcademic Degree=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Software Development","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Software Development","offsetgroup":"Software Development","orientation":"h","showlegend":true,"textposition":"auto","x":[1,1],"xaxis":"x","y":["Bachelor's","Masters"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=Computer Science\u003cbr\u003eNumber of Individuals=%{x}\u003cbr\u003eAcademic Degree=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Computer Science","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Computer Science","offsetgroup":"Computer Science","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["Undergraduate"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolo ...

# %%
# Donut Chart
fig = px.pie(df, values='Count', names='Degree',
             title='Distribution of Interest in AI Learning Support by Degree',
             hole=.3,
             color_discrete_sequence=px.colors.sequential.Plasma,
             template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d754b4be-e71f-4cb8-ad7d-0e6bb34a21f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d754b4be-e71f-4cb8-ad7d-0e6bb34a21f5")) {                    Plotly.newPlot(                        "d754b4be-e71f-4cb8-ad7d-0e6bb34a21f5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Degree=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Bachelor's","Bachelor's","Undergraduate","Undergraduate","Bachelor's","Bachelor's","Masters","Masters","Masters","Undergraduate","Undergraduate"],"legendgroup":"","name":"","showlegend":true,"values":[2,2,2,2,1,1,1,1,1,1,1],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"lin ...

# %% [markdown]
# **Insights**

# %% [markdown]
# **The data results indicate:**
#
# **Undergraduate students** from **Information Technology and Web Development** departments show an **equal interest in AI**, with a count of 2 respectively.
#
# **Bachelor's degree** holders from **Business Management and Marketing departments** also demonstrate a **similar interest in AI**, each with a count of 2.
#
# Only one Masters student each from Information Technology, Marketing, and Software Development departments are interested in AI.
#
# One Undergraduate student each from Business Management and Computer Science departments show an interest in AI.
#
# These results suggest that the recruitment strategy should **primarily target** **Undergraduate students in Information Technology and Web Development** departments, followed by Bachelor's degree holders in Business Management and Marketing departments.

# %% [markdown]
# **Identification of the most popular academic departments among the respondents.**

# %%
df_general
# Out:
#           Name         Degree              Department  \
# 0    Student 1     Bachelor's         Web Development
# 1    Student 2        Masters        Computer Science
# 2    Student 3  Undergraduate         Web Development
# 3    Student 4     Bachelor's    Software Development
# 4    Student 5     Bachelor's               Marketing
# 5    Student 6        Masters  Information Technology
# 6    Student 7  Undergraduate        Computer Science
# 7    Student 8     Bachelor's               Marketing
# 8    Student 9        Masters    Software Development
# 9   Student 10  Undergraduate         Web Development
# 10  Student 11        Masters     Business Management
# 11  Student 12  Undergraduate  Information Technology
# 12  Student 13  Undergraduate  Information Technology
# 13  Student 14        Masters    Software Development
# 14  Student 15  Undergraduate     Business Management
# 15  Student 16     Bachelor's    Software Development
# 16  Student 17     Bachelor's     Business Management
# 17  Student 18        Masters         Web Development
# 18  Student 19  Undergraduate        Computer Science
# 19  Student 20     Bachelor's        Computer Science
# 20  Student 21        Masters               Marketing
# 21  Student 22     Bachelor's     Business Management
# 22  Student 23  Undergraduate  Information Technology
#
#                                            Motivation Career_Support  \
# 0   to help me develop strategies that can help me...            Yes
# 1   creating models that can produce new data samp...            Yes
# 2          All about gemerayive AI and how to use AI             Yes
# 3                                 Help me with my job            Yes
# 4                          something about our future             No
# 5                         Utilize generative AI tools            Yes
# 6                       Explore AI work opportunities            Yes
# 7                             Work with Google Gemini            Yes
# 8    How to find a job job with emerging tehcnologies             No
# 9                         Integrate AI with my career            Yes
# 10                      Find the right career pathway            Yes
# 11                How to use AI to leverage my career            Yes
# 12                                     Grow my career             No
# 13                                     Find a new job             No
# 14                         Enhance my teaching skills            Yes
# 15                    Keep updated on AI advancements            Yes
# 16     Enhance my knowledge in data analysis using AI            Yes
# 17        Upgrade my career to be able to work withAI             No
# 18  I want to have full knowledge about how the ai...            Yes
# 19   Understand how it works and apply it to finance              No
# 20      To use AI tools in different business aspects             No
# 21                             How to work on ChatGPT            Yes
# 22         Be able to clearly understand how Ai works             No
#
#    Learning_Support
# 0               Yes
# 1                No
# 2               Yes
# 3               Yes
# 4               Yes
# 5               Yes
# 6                No
# 7               Yes
# 8               Yes
# 9               Yes
# 10               No
# 11              Yes
# 12              Yes
# 13               No
# 14              Yes
# 15               No
# 16              Yes
# 17               No
# 18              Yes
# 19               No
# 20              Yes
# 21              Yes
# 22               No

# %%
df_popular = df_general['Department'].value_counts().reset_index()
df_popular
# Out:
#                Department  count
# 0         Web Development      4
# 1        Computer Science      4
# 2    Software Development      4
# 3  Information Technology      4
# 4     Business Management      4
# 5               Marketing      3

# %% [markdown]
# **Data visualization**

# %%
fig = px.bar(df_popular,
             x='count',
             y='Department',
             title='Most Popular Academic Departments Among Respondents',
             labels={'count':'Number of Respondents',
                     'Department':'Department'},
             color='Department',
             template='plotly_dark')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2a7ea256-eb76-4840-acee-10dc1a6b5463" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a7ea256-eb76-4840-acee-10dc1a6b5463")) {                    Plotly.newPlot(                        "2a7ea256-eb76-4840-acee-10dc1a6b5463",                        [{"alignmentgroup":"True","hovertemplate":"Department=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Web Development","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Web Development","offsetgroup":"Web Development","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Web Development"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Computer Science","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Computer Science","offsetgroup":"Computer Science","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Computer Science"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Software Development","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Software Development","offsetgroup":"Software Development","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Software Development"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Information Technology","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Information Technology","offsetgroup":"Information Technology","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Information Technology"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Business Management","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Business Management","offsetgroup":"Business Management","orientation":"h","showlegend":true,"textposition":"auto","x":[4],"xaxis":"x","y":["Business Management"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Department=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Marketing","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Marketing","offsetgroup":"Marketing","orientation":"h","showlegend":true,"textposition":"auto","x":[3],"xaxis":"x","y":["Marketing"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111 ...

# %% [markdown]
# **Insights**

# %% [markdown]
# **The analytics task reveals the following:**
#
# Among the respondents, the most popular academic departments are **Web Development, Computer Science, Software Development, Information Technology, and Business Management**, each with a Respondent Count of 4.
# These departments are followed closely by Marketing, which has a Respondent Count of 3.
# It's worth noting that **there is no single stand-out department**; the top five are equally popular.
# The data does not show a clear preference for either technical (i.e., Web Development, Computer Science, Software Development, Information Technology) or business-oriented (i.e., Business Management, Marketing) departments.
# Further analysis or more data might be needed to identify any significant differences or trends among the respondents' academic department choices.

# %% [markdown]
# **Analysis of the proportion of respondents requiring online career and learning support in AI.**

# %%
df_general.head(1)
# Out:
#         Name      Degree       Department  \
# 0  Student 1  Bachelor's  Web Development
#
#                                           Motivation Career_Support  \
# 0  to help me develop strategies that can help me...            Yes
#
#   Learning_Support
# 0              Yes

# %%
# Calculate proportions
df_career_support = df_general['Career_Support'].value_counts(normalize=True).reset_index()
df_learning_support = df_general['Learning_Support'].value_counts(normalize=True).reset_index()

# %%
df_career_support
# Out:
#   Career_Support  proportion
# 0            Yes    0.652174
# 1             No    0.347826

# %%
df_learning_support
# Out:
#   Learning_Support  proportion
# 0              Yes    0.652174
# 1               No    0.347826

# %%
# Create bar chart
fig = px.bar(df_career_support, y='Career_Support', x='proportion',
             color='Career_Support',
             title='Proportion of respondents requiring online career support',
             labels={'proportion':'Proportion of respondents',
                     'Career_Support': 'Need Online Career Support'},
             template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="879de2bd-5b7a-4d4c-afe4-e321e6d246e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("879de2bd-5b7a-4d4c-afe4-e321e6d246e1")) {                    Plotly.newPlot(                        "879de2bd-5b7a-4d4c-afe4-e321e6d246e1",                        [{"alignmentgroup":"True","hovertemplate":"Need Online Career Support=%{y}\u003cbr\u003eProportion of respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.6521739130434783],"xaxis":"x","y":["Yes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Need Online Career Support=%{y}\u003cbr\u003eProportion of respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"h","showlegend":true,"textposition":"auto","x":[0.34782608695652173],"xaxis":"x","y":["No"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"], ...

# %%
# Create donut chart
fig = px.pie(df_career_support, values='proportion', names='Career_Support',
             title='Proportional distribution of respondents requiring online career support',
             template='plotly_dark', hole=0.3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="956abee5-8225-4103-a44b-6c40fc7c25df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("956abee5-8225-4103-a44b-6c40fc7c25df")) {                    Plotly.newPlot(                        "956abee5-8225-4103-a44b-6c40fc7c25df",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Career_Support=%{label}\u003cbr\u003eproportion=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Yes","No"],"legendgroup":"","name":"","showlegend":true,"values":[0.6521739130434783,0.34782608695652173],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type": ...

# %%
# Create horizontal bar chart for learning support
fig = px.bar(df_learning_support, y='Learning_Support', x='proportion',
             color='Learning_Support',
             title='Proportion of respondents requiring online learning support in AI',
             labels={'proportion':'Proportion of respondents',
                     'Learning_Support': 'Require Online Learning Support in AI'},
             template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ccfe3486-5f23-42c9-b685-e591126a1f7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccfe3486-5f23-42c9-b685-e591126a1f7b")) {                    Plotly.newPlot(                        "ccfe3486-5f23-42c9-b685-e591126a1f7b",                        [{"alignmentgroup":"True","hovertemplate":"Require Online Learning Support in AI=%{y}\u003cbr\u003eProportion of respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.6521739130434783],"xaxis":"x","y":["Yes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Require Online Learning Support in AI=%{y}\u003cbr\u003eProportion of respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"h","showlegend":true,"textposition":"auto","x":[0.34782608695652173],"xaxis":"x","y":["No"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777 ...

# %%
# Create donut chart
fig = px.pie(df_learning_support, values='proportion', names='Learning_Support',
             title='Proportional distribution of respondents requiring online learning support in AI',
             template='plotly_dark', hole=0.3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3ccdbf5d-b37c-490a-973b-7e0a5873e234" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ccdbf5d-b37c-490a-973b-7e0a5873e234")) {                    Plotly.newPlot(                        "3ccdbf5d-b37c-490a-973b-7e0a5873e234",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Learning_Support=%{label}\u003cbr\u003eproportion=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Yes","No"],"legendgroup":"","name":"","showlegend":true,"values":[0.6521739130434783,0.34782608695652173],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type ...

# %% [markdown]
# The analytics task reveals that a significant majority of respondents expressed a need for online career and learning support in AI.
#
# Approximately **65.2% **of respondents indicated a **requirement for online learning and career support**.
# In contrast, only about 34.8% of participants responded negatively to the same inquiry.
# Therefore, there's a **substantial demand** for online resources that **cater to AI learning and career development**.
# The data suggests an opportunity to enhance online support systems or introduce new, comprehensive platforms that directly address this need.

# %% [markdown]
# **Determination of the most common level of educational attainment among respondents interested in learning generative AI.**

# %%
# filter data by respondents interested in learning generative AI
df_intrested_AI = df_general[~df_general['Motivation'].isnull()]
df_intrested_AI.shape[0]
# Out:
# 23

# %%
df_intrested_AI['Motivation'].value_counts().sort_values(ascending=False)
# Out:
# Motivation
# to help me develop strategies that can help me in my career                                                  1
# creating models that can produce new data samples that resemble the training data they were provided with    1
# All about gemerayive AI and how to use AI                                                                    1
# Help me with my job                                                                                          1
# something about our future                                                                                   1
# Utilize generative AI tools                                                                                  1
# Explore AI work opportunities                                                                                1
# Work with Google Gemini                                                                                      1
# How to find a job job with emerging tehcnologies                                                             1
# Integrate AI with my career                                                                                  1
# Find the right career pathway                                                                                1
# How to use AI to leverage my career                                                                          1
# Grow my career                                                                                               1
# Find a new job                                                                                               1
# Enhance my teaching skills                                                                                   1
# Keep updated on AI advancements                                                                              1
# Enhance my knowledge in data analysis using AI                                                               1
# Upgrade my career to be able to work withAI                                                                  1
# I want to have full knowledge about how the ai work                                                          1
# Understand how it works and apply it to finance                                                              1
# To use AI tools in different business aspects                                                                1
# How to work on ChatGPT                                                                                       1
# Be able to clearly understand how Ai works                                                                   1
# Name: count, dtype: int64

# %%
# determine the most common level of educational attainment
df_education_and_motivation_AI = df_intrested_AI['Degree'].value_counts().reset_index()

df_education_and_motivation_AI
# Out:
#           Degree  count
# 0     Bachelor's      8
# 1  Undergraduate      8
# 2        Masters      7

# %% [markdown]
# **Data visualization**

# %%
fig = px.bar(df_education_and_motivation_AI,
             x='count',
             y='Degree',
             color='Degree',
             title='Educational Attainment of AI Learners',
             labels={'count':'Number of Respondents',
                     'Degree':'Educational Level'},
             color_discrete_sequence=px.colors.qualitative.Pastel,
             template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="35b3663b-f193-4fb9-9a35-9934fb05a99b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35b3663b-f193-4fb9-9a35-9934fb05a99b")) {                    Plotly.newPlot(                        "35b3663b-f193-4fb9-9a35-9934fb05a99b",                        [{"alignmentgroup":"True","hovertemplate":"Educational Level=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bachelor's","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"Bachelor's","offsetgroup":"Bachelor's","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["Bachelor's"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Educational Level=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Undergraduate","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Undergraduate","offsetgroup":"Undergraduate","orientation":"h","showlegend":true,"textposition":"auto","x":[8],"xaxis":"x","y":["Undergraduate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Educational Level=%{y}\u003cbr\u003eNumber of Respondents=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Masters","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Masters","offsetgroup":"Masters","orientation":"h","showlegend":true,"textposition":"auto","x":[7],"xaxis":"x","y":["Masters"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %% [markdown]
# **Insights **

# %% [markdown]
# **The analysis of the educational level of respondents interested in learning generative AI reveals the following:**
#
# The **most common level of educational** attainment is a tie between those with a **Bachelor's degree** and those who are **Undergraduates**, each category having 8 respondents.
# The next common level of educational attainment is a Master's degree with 7 respondents.
# This suggests that the interest in generative AI is spread across different stages of higher education, with a slight emphasis on the undergraduate level and those who have completed a Bachelor's degree.
